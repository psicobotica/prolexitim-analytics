# %% [markdown]
# # Prolexitim Analytics (NLP)
# ## NLP Dataset Preparation and Pre-processing
# ### Merging TAS-20 results with NLP data (text, sentiment, emotion)
# <hr>
# May 2019.<br> Prolexitim dataset version 1.1 (MPGS-TFM-Submission).<br>
# Raúl Arrabales Moreno (Psicobótica / Serendeepia Research)<br>
# <a target="_blank" href="http://www.conscious-robots.com/">http://www.conscious-robots.com/</a> <br>
# <hr>

# %% [markdown]
# ### Load dataset from CSV files

# %%
# Loading the tables

import pandas as pd 

nlp_dataset_path = "D:\\Dropbox-Array2001\\Dropbox\\UNI\\MPGS\\2_TFM\\Datos\\prolexitim-nlp-1.1.csv"
tas_dataset_path = "D:\\Dropbox-Array2001\\Dropbox\\UNI\\MPGS\\2_TFM\\Datos\\prolexitim-tas-1.1.csv"

nlp_df = pd.read_csv(nlp_dataset_path,header=0,delimiter="\t") 
tas_df = pd.read_csv(tas_dataset_path,header=0,delimiter="\t")

# %%
# Check
nlp_df.head()
# Out:
#    Unnamed: 0  RowId                              code  card  hum mode  \
# 0           0      1  b7adde8a9eec8ce92b5ee0507ce054a4   13V    1    T
# 1           1      2  b7adde8a9eec8ce92b5ee0507ce054a4  18NM    2    T
# 2           2      3  b7adde8a9eec8ce92b5ee0507ce054a4  12VN    0    T
# 3           3      4  76ef63369f7d5b6597a543017e1ef578  12VN    0    T
# 4           4      5  76ef63369f7d5b6597a543017e1ef578    10    2    T
#
#      time  G-score  G-magnitude  Azure-TA  ...  \
# 0  200000     -0.2          0.2      0.62  ...
# 1  200000     -0.5          0.5      0.41  ...
# 2  200000      0.0          1.2      0.63  ...
# 3  200000      0.0          0.1      0.89  ...
# 4  200000      0.3          0.1      0.24  ...
#
#                                              Text-EN nlu-sentiment  nlu-label  \
# 0  It was a child sitting in the barn and thinkin...     -0.640157   negative
# 1  A mother who is comforting her son, after givi...      0.000000    neutral
# 2  A swam with an abandoned boat. Let's see what ...      0.265769   positive
# 3  It was a beautiful place, with a boat, a littl...     -0.353556   negative
# 4  It was once a husband and wife, who loved each...     -0.552068   negative
#
#     nlu-joy  nlu-anger  nlu-disgust  nlu-sadness  nlu-fear  es-len  en-len
# 0  0.317920   0.143086     0.422023     0.173421  0.098997     115     124
# 1  0.285100   0.168727     0.057098     0.362623  0.109176     110     115
# 2  0.039779   0.205065     0.244164     0.164005  0.481812      93      96
# 3  0.208997   0.007244     0.008434     0.698307  0.190991     255     244
# 4  0.367801   0.063256     0.095947     0.469062  0.103351     184     184
#
# [5 rows x 21 columns]

# %%
# Check
tas_df.head()
# Out:
#    Unnamed: 0  NLP                              code  TAS20  F1  F2  F3  \
# 0           0    0  be8f0c722d0a0f4cd9d92c503e6f7583     42  16  10  16
# 1           1    1  608af5455da8c250a87f81a5ed5c1942     55  15  20  15
# 2           2    1  bc39e22ca5dba59fbd97c27987878f56     40  16   9  15
# 3           3    0  a2caa2eaccf99705bf39f6aeaee00ee3     40  13  10  17
# 4           4    1  20cd825cadb95a71763bad06e142c148     40  12  10  18
#
#    Tas20Time  Sex  Gender  ...  Dhand  Studies  SClass  Siblings  SibPos  \
# 0     254305    1       1  ...      1        5       2         6       2
# 1     103425    1       1  ...      2        7       2         5       5
# 2     201637    2       2  ...      1        5       2         2       2
# 3     242202    2       2  ...      1        5       2         3       1
# 4     155945    2       2  ...      1        5       2         1       1
#
#    Origin Resid Rtime  Ethnic         Job
# 0      ES    ES    -1  Iberic  Psychology
# 1      ES    ES    -1  Iberic  Psychology
# 2      ES    ES    -1  Iberic  Psychology
# 3      ES    ES    -1  Iberic  Psychology
# 4      ES    ES    -1  Iberic  Psychology
#
# [5 rows x 21 columns]

# %%
# Column rename so code matches both tables

tas_df.rename(columns={'Code':'code'}, inplace=True)

# %%
tas_df.dtypes
# Out:
# Unnamed: 0     int64
# NLP            int64
# code          object
# TAS20          int64
# F1             int64
# F2             int64
# F3             int64
# Tas20Time      int64
# Sex            int64
# Gender         int64
# Age            int64
# Dhand          int64
# Studies        int64
# SClass         int64
# Siblings       int64
# SibPos         int64
# Origin        object
# Resid         object
# Rtime          int64
# Ethnic        object
# Job           object
# dtype: object

# %%
# Fix wrong codes:

nlp_df['code'] = nlp_df['code'].str.replace('ceaee8e1286ad5dbb921b38f529c1c6b','2f052997edc3c005cc16cd263210f05f',regex=True)
nlp_df['code'] = nlp_df['code'].str.replace('40cf09c4faba45471aa7e6f28f2a8b1b','1384903a9d83e20ccd863fe23876e919',regex=True)
nlp_df['code'] = nlp_df['code'].str.replace('116457052e0ddfbabafad6f14feb1ab0','116457052e0ddfbabafad6f14feb1ab',regex=True)
nlp_df['code'] = nlp_df['code'].str.replace('1057c3565f4c5b60e4765746d2e475ef','8a17721b00de1ac4e9e771b3d06c3131',regex=True)
nlp_df['code'] = nlp_df['code'].str.replace('272f153b22c299914f25010e8dab62f9','107b920c3318629af25cd9fe09c2bd25',regex=True)
nlp_df['code'] = nlp_df['code'].str.replace('1e79d86ac69decf2c5e34db8a3308106','8455c12aed5a184b635e816f798b336f',regex=True)

# %% [markdown]
# ### Joining NLP exemplars with TAS-20 scores

# %%
# Perform the left join

prolex_df = pd.merge(nlp_df, tas_df, on='code', how='left')

# %%
# Check
prolex_df.dtypes
# Out:
# RowId              int64
# code              object
# card              object
# hum                int64
# mode              object
# time               int64
# G-score          float64
# G-magnitude      float64
# Azure-TA         float64
# Text              object
# Text-EN           object
# nlu-sentiment    float64
# nlu-label         object
# nlu-joy          float64
# nlu-anger        float64
# nlu-disgust      float64
# nlu-sadness      float64
# nlu-fear         float64
# es-len             int64
# en-len             int64
# NLP              float64
# TAS20            float64
# F1               float64
# F2               float64
# F3               float64
# Tas20Time        float64
# Sex              float64
# Gender           float64
# Age              float64
# Dhand            float64
# Studies          float64
# SClass           float64
# Siblings         float64
# SibPos           float64
# Origin            object
# Resid             object
# Rtime            float64
# Ethnic            object
# Job               object
# dtype: object

# %%
# remove unused columns
prolex_df = prolex_df.drop(columns="Unnamed: 0_x");
prolex_df = prolex_df.drop(columns="Unnamed: 0_y");

# %%
prolex_df.head(n=30)
# Out:
# 5           0.9      0.34  Erase una vez un niño que se encontraba muy tr...
# 6           0.3      0.16  Alguien que está triste o cansado de algo y es...
# 7           0.2      0.82  Erase una vez un bosque encantado en el cual n...
# 8           0.8      0.69  Erase una vez un niño que le gustaba descubrir...
# 9           0.3      0.45  Pues no sé. Puede haber llegado por la noche d...
# 10          1.6      0.07  Le obligan a tocar el violín y no le gusta, es...
# 11          0.9      0.17  Un niño que a lo mejor está abandonado por sus...
# 12          0.6      0.60  Parece que están atendiendo a algo, podría ser...
# 13          0.2      0.16  Es un poquito abandonado y triste, pero bueno ...
# 14          0.6      0.09  Me da sensación de que le ha pasado algo y que...
# 15          0.1      0.46  Pues esto es un niño que está tomando el sol y...
# 16          0.4      0.48  Es una mujer que está besando el pecho a su ma...
# 17          0.6      0.39  Unos cazadores que están en el campo y están d...
# 18          0.1      0.45  Hay unos dragones que acaban de aterrizar en u...
# 19          0.7      0.52  Esto es en la época de los dinosaurios. Esto e...
# 20          0.0      0.71  Son dos señores viendo la tele, que están vien...
# 21          0.8      0.00  Esto es una señora que le acaban de dar una ma...
# 22          0.4      0.59  Son unos señores que estaban trabajando en el ...
# 23          0.9      0.15  La frustración de aprender un nuevo instrument...
# 24          0.6      0.34  Es una pareja y el hombre se encuentra arrepen...
# 25          0.6      0.51  A mí me recuerda a los chavales cuando no sabí...
# 26          0.5      0.24  Estragos de la sequía, ya que donde antes habí...
# 27          0.5      0.34  Había una vez una mujer que vivía sola, pero c...
# 28          0.9      0.45  Hay un niño cuyos padres le han oblidado a toc...
# 29          0.8      0.69  Un día me propuse cruzar la montaña, subí a lo...
#
#     ... Dhand  Studies SClass  Siblings  SibPos  Origin  Resid  Rtime  Ethnic  \
# 0   ...   1.0      4.0    2.0       5.0     3.0      ES     ES   -1.0  Iberic
# 1   ...   1.0      4.0    2.0       5.0     3.0      ES     ES   -1.0  Iberic
# 2   ...   1.0      4.0    2.0       5.0     3.0      ES     ES   -1.0  Iberic
# 3   ...   1.0      1.0    2.0       3.0     3.0      ES     ES   -1.0  Iberic
# 4   ...   1.0      1.0    2.0       3.0     3.0      ES     ES   -1.0  Iberic
# 5   ...   1.0      1.0    2.0       3.0     3.0      ES     ES   -1.0  Iberic
# 6   ...   1.0      5.0    2.0       2.0     1.0      ES     ES   -1.0  Iberic
# 7   ...   1.0      5.0    2.0       2.0     1.0      ES     ES   -1.0  Iberic
# 8   ...   1.0      5.0    2.0       2.0     1.0      ES     ES   -1.0  Iberic
# 9   ...   1.0      6.0    2.0       4.0     4.0      ES     ES   -1.0  Iberic
# 10  ...   1.0      6.0    2.0       4.0     4.0      ES     ES   -1.0  Iberic
# 11  ...   1.0      6.0    2.0       4.0     4.0      ES     ES   -1.0  Iberic
# 12  ...   1.0      6.0    2.0       4.0     4.0      ES     ES   -1.0  Iberic
# 13  ...   1.0      6.0    2.0       4.0     4.0      ES     ES   -1.0  Iberic
# 14  ...   1.0      5.0    2.0       2.0     1.0      ES     ES   -1.0  Iberic
# 15  ...   1.0      5.0    2.0       2.0     1.0      ES     ES   -1.0  Iberic
# 16  ...   1.0      5.0    2.0       2.0     1.0      ES     ES   -1.0  Iberic
# 17  ...   1.0      5.0    2.0       2.0     1.0      ES     ES   -1.0  Iberic
# 18  ...   1.0      5.0    2.0       2.0     1.0      ES     ES   -1.0  Iberic
# 19  ...   1.0      5.0    2.0       1.0     1.0      ES     ES   -1.0  Iberic
# 20  ...   1.0      5.0    2.0       1.0     1.0      ES     ES   -1.0  Iberic
# 21  ...   1.0      5.0    2.0       1.0     1.0      ES     ES   -1.0  Iberic
# 22  ...   1.0      5.0    2.0       1.0     1.0      ES     ES   -1.0  Iberic
# 23  ...   1.0      5.0    2.0       1.0     2.0      ES     ES   -1.0  Iberic
# 24  ...   1.0      5.0    2.0       1.0     2.0      ES     ES   -1.0  Iberic
# 25  ...   1.0      5.0    2.0       1.0     2.0      ES     ES   -1.0  Iberic
# 26  ...   1.0      5.0    2.0       1.0     2.0      ES     ES   -1.0  Iberic
# 27  ...   2.0      3.0    2.0       2.0     1.0      ES     ES   -1.0  Iberic
# 28  ...   2.0      3.0    2.0       2.0     1.0      ES     ES   -1.0  Iberic
# 29  ...   2.0      3.0    2.0       2.0     1.0      ES     ES   -1.0  Iberic
#
#          Job
# 0    Manager
# 1    Manager
# 2    Manager
# 3    Retired
# 4    Retired
# 5    Retired
# 6    Student
# 7    Student
# 8    Student
# 9   Engineer
# 10  Engineer
# 11  Engineer
# 12  Engineer
# 13  Engineer
# 14   Manager
# 15   Manager
# 16   Manager
# 17   Manager
# 18   Manager
# 19   Teacher
# 20   Teacher
# 21   Teacher
# 22   Teacher
# 23  Engineer
# 24  Engineer
# 25  Engineer
# 26  Engineer
# 27  Engineer
# 28  Engineer
# 29  Engineer
#
# [30 rows x 39 columns]

# %%
prolex_df.tail(n=30)
# Out:
#      RowId                              code  card  hum mode     time  \
# 308    309  21f81d0e1462187617f7f93d3e34a90d    11    0    W  1156305
# 309    310  21f81d0e1462187617f7f93d3e34a90d  13HM    2    W  1156305
# 310    311  bd0f72617b5ea094ac4accb397070d8d     1    1    W  1393972
# 311    312  bd0f72617b5ea094ac4accb397070d8d   9VH    4    W  1393972
# 312    313  bd0f72617b5ea094ac4accb397070d8d    11    0    W  1393972
# 313    314  bd0f72617b5ea094ac4accb397070d8d  13HM    2    W  1393972
# 314    315  f0b6d248520d5d24a7553a41ee5faaa9     1    1    W  2036261
# 315    316  f0b6d248520d5d24a7553a41ee5faaa9   9VH    4    W  2036261
# 316    317  f0b6d248520d5d24a7553a41ee5faaa9    11    0    W  2036261
# 317    318  f0b6d248520d5d24a7553a41ee5faaa9  13HM    2    W  2036261
# 318    319  bc39e22ca5dba59fbd97c27987878f56     1    1    W   103020
# 319    320  bc39e22ca5dba59fbd97c27987878f56   9VH    4    W   103020
# 320    321  bc39e22ca5dba59fbd97c27987878f56    11    0    W   103020
# 321    322  bc39e22ca5dba59fbd97c27987878f56  13HM    2    W   103020
# 322    323  9441e8d938e3c168a4b3e82e52903416     1    1    W   570494
# 323    324  9441e8d938e3c168a4b3e82e52903416   9VH    4    W   570494
# 324    325  9441e8d938e3c168a4b3e82e52903416    11    0    W   570494
# 325    326  9441e8d938e3c168a4b3e82e52903416  13HM    2    W   570494
# 326    327  2f052997edc3c005cc16cd263210f05f     1    1    W  2839201
# 327    328  2f052997edc3c005cc16cd263210f05f   9VH    4    W  2839201
# 328    329  2f052997edc3c005cc16cd263210f05f    11    0    W  2839201
# 329    330  2f052997edc3c005cc16cd263210f05f  13HM    2    W  2839201
# 330    331  608af5455da8c250a87f81a5ed5c1942     1    1    W   220357
# 331    331  608af5455da8c250a87f81a5ed5c1942     1    1    W   220357
# 332    332  608af5455da8c250a87f81a5ed5c1942   9VH    4    W   220357
# 333    332  608af5455da8c250a87f81a5ed5c1942   9VH    4    W   220357
# 334    333  608af5455da8c250a87f81a5ed5c1942    11    0    W   220357
# 335    333  608af5455da8c250a87f81a5ed5c1942    11    0    W   220357
# 336    334  608af5455da8c250a87f81a5ed5c1942  13HM    2    W   220357
# 337    334  608af5455da8c250a87f81a5ed5c1942  13HM    2    W   220357
#
#      G-score  G-magnitude  Azure-TA  \
# 308     -0.2          0.2      0.51
# 309      0.1          0.5      0.73
# 310     -0.4          2.9      0.39
# 311     -0.7          0.7      0.72
# 312      0.3          2.0      0.81
# 313     -0.1          0.7      0.55
# 314     -0.1          0.3      0.39
# 315      0.3          0.3      0.63
# 316      0.0          4.8      0.58
# 317     -0.1          2.5      0.41
# 318     -0.3          0.3      0.36
# 319      0.1          0.1      0.59
# 320      0.6          0.6      0.52
# 321      0.0          0.0      0.05
# 322      0.0          1.2      0.41
# 323      0.0          0.8      0.65
# 324     -0.3          1.6      0.48
# 325     -0.3          1.6      0.29
# 326     -0.9          0.9      0.30
# 327      0.4          0.9      0.58
# 328     -0.3          1.0      0.44
# 329     -0.8          0.8      0.34
# 330     -0.6          0.6      0.22
# 331     -0.6          0.6      0.22
# 332      0.0          0.3      0.40
# 333      0.0          0.3      0.40
# 334     -0.1          0.8      0.23
# 335     -0.1          0.8      0.23
# 336      0.1          1.0      0.58
# 337      0.1          1.0      0.58
#
#                                                   Text  ... Dhand  Studies  \
# 308  una ciudad perdida en mitad de la nada, donde ...  ...   1.0      5.0
# 309  Érase una vez... un cuarto, un cuarto visitado...  ...   1.0      5.0
# 310  Érase una vez un niño castaño de unos 7 años q...  ...   1.0      6.0
# 311  en la época de los 80, un grupo de ladrones qu...  ...   1.0      6.0
# 312  un lugar psicodelico al que nadie podía accede...  ...   1.0      6.0
# 313  una pareja enamorada que tras hacer el amor ti...  ...   1.0      6.0
# 314  Jorge es un chico de 10 años que no le gusta e...  ...   1.0      5.0
# 315  Eran 4 amigos que trabajaban en el campo y des...  ...   1.0      5.0
# 316  se escuchaba que en el pueblo existía un tesor...  ...   1.0      5.0
# 317  Marco es un doctor conocido de la ciudad. \r\n...  ...   1.0      5.0
# 318  es un niño pensando en cual es la respuesta de...  ...   1.0      5.0
# 319                              soldados descansando   ...   1.0      5.0
# 320                                        Una cascada  ...   1.0      5.0
# 321          hombre llorando porque su mujer ha muerto  ...   1.0      5.0
# 322  Érase una vez un niño que debía acudir a clase...  ...   1.0      6.0
# 323  Varios hombres habían decidido descansar en me...  ...   1.0      6.0
# 324  El fin del camino empedrado estaba cerca, si t...  ...   1.0      6.0
# 325  Acababa de fallecer su mujer. Estaba desconsol...  ...   1.0      6.0
# 326  Érase una vez un niño al que no le gustaba la ...  ...   1.0      4.0
# 327  Érase una vez un campesino que durante las hor...  ...   1.0      4.0
# 328  Érase una ve un lugar maravilloso, donde la ma...  ...   1.0      4.0
# 329  Érase una vez un hombre que no amaba a su muje...  ...   1.0      4.0
# 330  El niño estaba sangrando por la boca porque se...  ...   2.0      7.0
# 331  El niño estaba sangrando por la boca porque se...  ...   2.0      7.0
# 332  Se habían pasado todo el día corriendo y jugan...  ...   2.0      7.0
# 333  Se habían pasado todo el día corriendo y jugan...  ...   2.0      7.0
# 334  Hay unos toros que están enfadados y se prepar...  ...   2.0      7.0
# 335  Hay unos toros que están enfadados y se prepar...  ...   2.0      7.0
# 336  Un señor que se arrepiente de haber matado a s...  ...   2.0      7.0
# 337  Un señor que se arrepiente de haber matado a s...  ...   2.0      7.0
#
#     SClass  Siblings  SibPos  Origin  Resid  Rtime  Ethnic             Job
# 308    2.0       4.0     3.0      ES     ES   -1.0  Iberic       Marketing
# 309    2.0       4.0     3.0      ES     ES   -1.0  Iberic       Marketing
# 310    2.0       1.0     1.0      ES     ES   -1.0  Iberic       Marketing
# 311    2.0       1.0     1.0      ES     ES   -1.0  Iberic       Marketing
# 312    2.0       1.0     1.0      ES     ES   -1.0  Iberic       Marketing
# 313    2.0       1.0     1.0      ES     ES   -1.0  Iberic       Marketing
# 314    2.0       2.0     2.0      MX     ES    1.0   Latin       Marketing
# 315    2.0       2.0     2.0      MX     ES    1.0   Latin       Marketing
# 316    2.0       2.0     2.0      MX     ES    1.0   Latin       Marketing
# 317    2.0       2.0     2.0      MX     ES    1.0   Latin       Marketing
# 318    2.0       2.0     2.0      ES     ES   -1.0  Iberic      Psychology
# 319    2.0       2.0     2.0      ES     ES   -1.0  Iberic      Psychology
# 320    2.0       2.0     2.0      ES     ES   -1.0  Iberic      Psychology
# 321    2.0       2.0     2.0      ES     ES   -1.0  Iberic      Psychology
# 322    2.0       2.0     1.0      ES     ES   -1.0  Iberic  Data Scientist
# 323    2.0       2.0     1.0      ES     ES   -1.0  Iberic  Data Scientist
# 324    2.0       2.0     1.0      ES     ES   -1.0  Iberic  Data Scientist
# 325    2.0       2.0     1.0      ES     ES   -1.0  Iberic  Data Scientist
# 326    2.0       2.0     1.0      CO     ES   12.0   Latin         Manager
# 327    2.0       2.0     1.0      CO     ES   12.0   Latin         Manager
# 328    2.0       2.0     1.0      CO     ES   12.0   Latin         Manager
# 329    2.0       2.0     1.0      CO     ES   12.0   Latin         Manager
# 330    2.0       5.0     5.0      ES     ES   -1.0  Iberic      Psychology
# 331    2.0       5.0     5.0      ES     ES   -1.0  Iberic       Scientist
# 332    2.0       5.0     5.0      ES     ES   -1.0  Iberic      Psychology
# 333    2.0       5.0     5.0      ES     ES   -1.0  Iberic       Scientist
# 334    2.0       5.0     5.0      ES     ES   -1.0  Iberic      Psychology
# 335    2.0       5.0     5.0      ES     ES   -1.0  Iberic       Scientist
# 336    2.0       5.0     5.0      ES     ES   -1.0  Iberic      Psychology
# 337    2.0       5.0     5.0      ES     ES   -1.0  Iberic       Scientist
#
# [30 rows x 39 columns]

# %%
prolex_df.count()
# Out:
# RowId            338
# code             338
# card             338
# hum              338
# mode             338
# time             338
# G-score          338
# G-magnitude      338
# Azure-TA         338
# Text             338
# Text-EN          338
# nlu-sentiment    338
# nlu-label        336
# nlu-joy          338
# nlu-anger        338
# nlu-disgust      338
# nlu-sadness      338
# nlu-fear         338
# es-len           338
# en-len           338
# NLP              322
# TAS20            322
# F1               322
# F2               322
# F3               322
# Tas20Time        322
# Sex              322
# Gender           322
# Age              322
# Dhand            322
# Studies          322
# SClass           322
# Siblings         322
# SibPos           322
# Origin           322
# Resid            322
# Rtime            322
# Ethnic           322
# Job              322
# dtype: int64

# %%
# Check Nulls and NaNs
prolex_df[prolex_df.isnull().any(axis=1)]
# Out:
#      RowId                              code  card  hum mode    time  G-score  \
# 82      83  9d03e3a59f6ba89e93cb3db6f5ae54a7     1    1    W  341832     -0.7
# 83      84  9d03e3a59f6ba89e93cb3db6f5ae54a7   9VH    4    W  341832     -0.6
# 84      85  9d03e3a59f6ba89e93cb3db6f5ae54a7    11    0    W  341832      0.7
# 85      86  9d03e3a59f6ba89e93cb3db6f5ae54a7  13HM    2    W  341832     -0.1
# 126    127  71509121918c3bcb8eac7a59658bd644     1    1    W  750870      0.0
# 127    128  71509121918c3bcb8eac7a59658bd644   9VH    4    W  750870      0.9
# 128    129  71509121918c3bcb8eac7a59658bd644    11    0    W  750870      0.0
# 129    130  71509121918c3bcb8eac7a59658bd644  13HM    2    W  750870      0.3
# 138    139  d381cf2ee0ac9c9b5820936906d65472     1    1    W  563420     -0.6
# 139    140  d381cf2ee0ac9c9b5820936906d65472   9VH    4    W  563420      0.5
# 140    141  d381cf2ee0ac9c9b5820936906d65472    11    0    W  563420      0.0
# 141    142  d381cf2ee0ac9c9b5820936906d65472  13HM    2    W  563420      0.4
# 220    221  20cd825cadb95a71763bad06e142c148    11    0    W  152986      0.0
# 286    287  9d631daa9d628cb304c0319f4ff9de5d     1    1    W  493000     -0.9
# 287    288  9d631daa9d628cb304c0319f4ff9de5d   9VH    4    W  493000      0.5
# 288    289  9d631daa9d628cb304c0319f4ff9de5d    11    0    W  493000      0.8
# 289    290  9d631daa9d628cb304c0319f4ff9de5d  13HM    2    W  493000     -0.2
# 320    321  bc39e22ca5dba59fbd97c27987878f56    11    0    W  103020      0.6
#
#      G-magnitude  Azure-TA                                               Text  \
# 82           1.4      0.29  A pepito le obligan a tocar el violín y el pre...
# 83           0.6      0.67  Estos trabajadores después de una jornada inte...
# 84           0.7      0.44  Una cascada de agua fría que daba de beber a u...
# 85           0.3      0.44  Una mujer desnuda que perdió la vida en mitad ...
# 126          0.0      0.41  Un niño que debía tener una clase, pero tenía ...
# 127          0.9      0.86  Una fiesta muy alegre se realizó en un pueblit...
# 128          0.2      0.76  en un lugar muy lejano en el inicio de los tie...
# 129          1.1      0.45  luego de un parto difícil, un médico se recupe...
# 138          0.6      0.35  Un niño q cada día le obligaban a tocar el vio...
# 139          1.1      0.80  Después de un duro día de trabajo Javier se pu...
# 140          0.0      0.60  una cueva donde vivian en la prehistoria una f...
# 141          0.9      0.75  hay amores q matan ella siempre fue ella no pu...
# 220          0.0      0.50                                         acantilado
# 286          0.9      0.45  Un niño al que sus padres querían ver tocando ...
# 287          1.0      0.45  Unos hombres que habían estado trabajando al s...
# 288          0.8      0.92  Una cascada en medio de la selva, animales se ...
# 289          0.8      0.29  Un hombre se encuentra avergonzado y triste, s...
# 320          0.6      0.52                                        Una cascada
#
#      ... Dhand  Studies SClass  Siblings  SibPos  Origin  Resid  Rtime  \
# 82   ...   NaN      NaN    NaN       NaN     NaN     NaN    NaN    NaN
# 83   ...   NaN      NaN    NaN       NaN     NaN     NaN    NaN    NaN
# 84   ...   NaN      NaN    NaN       NaN     NaN     NaN    NaN    NaN
# 85   ...   NaN      NaN    NaN       NaN     NaN     NaN    NaN    NaN
# 126  ...   NaN      NaN    NaN       NaN     NaN     NaN    NaN    NaN
# 127  ...   NaN      NaN    NaN       NaN     NaN     NaN    NaN    NaN
# 128  ...   NaN      NaN    NaN       NaN     NaN     NaN    NaN    NaN
# 129  ...   NaN      NaN    NaN       NaN     NaN     NaN    NaN    NaN
# 138  ...   NaN      NaN    NaN       NaN     NaN     NaN    NaN    NaN
# 139  ...   NaN      NaN    NaN       NaN     NaN     NaN    NaN    NaN
# 140  ...   NaN      NaN    NaN       NaN     NaN     NaN    NaN    NaN
# 141  ...   NaN      NaN    NaN       NaN     NaN     NaN    NaN    NaN
# 220  ...   1.0      5.0    2.0       1.0     1.0      ES     ES   -1.0
# 286  ...   NaN      NaN    NaN       NaN     NaN     NaN    NaN    NaN
# 287  ...   NaN      NaN    NaN       NaN     NaN     NaN    NaN    NaN
# 288  ...   NaN      NaN    NaN       NaN     NaN     NaN    NaN    NaN
# 289  ...   NaN      NaN    NaN       NaN     NaN     NaN    NaN    NaN
# 320  ...   1.0      5.0    2.0       2.0     2.0      ES     ES   -1.0
#
#      Ethnic         Job
# 82      NaN         NaN
# 83      NaN         NaN
# 84      NaN         NaN
# 85      NaN         NaN
# 126     NaN         NaN
# 127     NaN         NaN
# 128     NaN         NaN
# 129     NaN         NaN
# 138     NaN         NaN
# 139     NaN         NaN
# 140     NaN         NaN
# 141     NaN         NaN
# 220  Iberic  Psychology
# 286     NaN         NaN
# 287     NaN         NaN
# 288     NaN         NaN
# 289     NaN         NaN
# 320  Iberic  Psychology
#
# [18 rows x 39 columns]

# %% [markdown]
# ### Save merged tables

# %%
prolex_dataset_path = "D:\\Dropbox-Array2001\\Dropbox\\UNI\\MPGS\\2_TFM\\Datos\\prolexitim-merged-1.1.csv"
prolex_df.to_csv(prolex_dataset_path, sep='\t', encoding='utf-8', index=False)

# %% [markdown]
# ### Generate specific tables for correlational analysis
# TAS versus Text analytics scores (without text)

# %%
tas_sentiment_df = prolex_df[["code", "TAS20", "F1", "F2", "F3", "card", "G-score", "G-magnitude", "Azure-TA", "nlu-sentiment", "nlu-label", "nlu-joy", "nlu-anger", "nlu-fear", "nlu-disgust", "nlu-sadness", "es-len" ]]
tas_sentiment_df
# Out:
#                                  code  TAS20    F1    F2    F3  card  G-score  \
# 0    b7adde8a9eec8ce92b5ee0507ce054a4   39.0  12.0  14.0  13.0   13V     -0.2
# 1    b7adde8a9eec8ce92b5ee0507ce054a4   39.0  12.0  14.0  13.0  18NM     -0.5
# 2    b7adde8a9eec8ce92b5ee0507ce054a4   39.0  12.0  14.0  13.0  12VN      0.0
# 3    76ef63369f7d5b6597a543017e1ef578   63.0  23.0  21.0  19.0  12VN      0.0
# 4    76ef63369f7d5b6597a543017e1ef578   63.0  23.0  21.0  19.0    10      0.3
# 5    76ef63369f7d5b6597a543017e1ef578   63.0  23.0  21.0  19.0     1     -0.3
# 6    3a7bc6a0450eda9cc016324a2ee5b749   56.0  18.0  20.0  18.0   3VH     -0.1
# 7    3a7bc6a0450eda9cc016324a2ee5b749   56.0  18.0  20.0  18.0    11      0.2
# 8    3a7bc6a0450eda9cc016324a2ee5b749   56.0  18.0  20.0  18.0   13N      0.8
# 9    4509cf6e9d9a624a3a809bf96cfbdbd7   38.0  12.0  14.0  12.0   3VH     -0.1
# 10   4509cf6e9d9a624a3a809bf96cfbdbd7   38.0  12.0  14.0  12.0   3VH      0.0
# 11   4509cf6e9d9a624a3a809bf96cfbdbd7   38.0  12.0  14.0  12.0   3VH     -0.4
# 12   4509cf6e9d9a624a3a809bf96cfbdbd7   38.0  12.0  14.0  12.0   7VH      0.3
# 14   0.083769     0.386833     0.747542     133
# 15   0.212412     0.079341     0.523983     143
# 16   0.169488     0.184404     0.164169     120
# 17   0.113837     0.048318     0.259464     146
# 18   0.153386     0.049654     0.169810     105
# 19   0.180393     0.298856     0.261692     202
# 20   0.095484     0.392379     0.431191      98
# 21   0.257619     0.138674     0.817432      89
# 22   0.143042     0.055827     0.178077     128
# 23   0.068022     0.011502     0.625058     134
# 24   0.246899     0.298520     0.358984     332
# 25   0.261804     0.096422     0.224488     375
# 26   0.270344     0.103555     0.269596     170
# 27   0.530950     0.059579     0.565432     304
# 28   0.039829     0.045668     0.499714     339
# 29   0.307003     0.071024     0.248585     207
# ..        ...          ...          ...     ...
# 308  0.166634     0.174043     0.627787     111
# 309  0.286948     0.103012     0.545690     174
# 310  0.079189     0.614240     0.737150     506
# 311  0.691199     0.098990     0.384051     208
# 312  0.073813     0.002436     0.256586     193
# 313  0.032545     0.030103     0.669697     297
# 314  0.197094     0.059196     0.557118     273
# 315  0.056336     0.213912     0.338440      99
# 316  0.511631     0.029490     0.468109     744
# 317  0.475162     0.500005     0.637760     505
# 318  0.219783     0.130279     0.146410      76
# 319  0.252124     0.145561     0.413048      21
# 320  0.000000     0.000000     0.000000       0
# 321  0.087470     0.071577     0.938631      41
# 322  0.112842     0.083778     0.278761     295
# 323  0.153831     0.333987     0.559956     315
# 324  0.305266     0.039984     0.635722     252
# 325  0.167577     0.016048     0.870575     241
# 326  0.075424     0.110732     0.488546     138
# 327  0.092618     0.034348     0.129203     385
# 328  0.106366     0.304006     0.428611     846
# 329  0.680889     0.069312     0.441927     324
# 330  0.156011     0.638413     0.116242     123
# 331  0.156011     0.638413     0.116242     123
# 332  0.312814     0.057144     0.616436     157
# 333  0.312814     0.057144     0.616436     157
# 334  0.440558     0.096720     0.104777     160
# 335  0.440558     0.096720     0.104777     160
# 336  0.172115     0.288493     0.552312     145
# 337  0.172115     0.288493     0.552312     145
#
# [338 rows x 17 columns]

# %% [markdown]
# Check and remove NA's

# %%
tas_sentiment_df.count()
# Out:
# code             338
# TAS20            322
# F1               322
# F2               322
# F3               322
# card             338
# G-score          338
# G-magnitude      338
# Azure-TA         338
# nlu-sentiment    338
# nlu-label        336
# nlu-joy          338
# nlu-anger        338
# nlu-fear         338
# nlu-disgust      338
# nlu-sadness      338
# es-len           338
# dtype: int64

# %%
tas_sentiment_df = tas_sentiment_df.dropna()

# %%
tas_sentiment_df.count()
# Out:
# code             320
# TAS20            320
# F1               320
# F2               320
# F3               320
# card             320
# G-score          320
# G-magnitude      320
# Azure-TA         320
# nlu-sentiment    320
# nlu-label        320
# nlu-joy          320
# nlu-anger        320
# nlu-fear         320
# nlu-disgust      320
# nlu-sadness      320
# es-len           320
# dtype: int64

# %%
### Export TAS Sentiment table

# %%
tas_sentiment_dataset_path = "D:\\Dropbox-Array2001\\Dropbox\\UNI\\MPGS\\2_TFM\\Datos\\prolexitim-sentiment-1.1.csv"
tas_sentiment_df.to_csv(tas_sentiment_dataset_path, sep='\t', encoding='utf-8', index=False)
